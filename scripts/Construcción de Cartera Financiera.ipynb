# %% [markdown]
# # CONSTRUCCIÓN DE CARTERA FINANCIERA

# %% [markdown]
# ### Librerías

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ### Lectura de Base de Datos

# %%
#salir de la ruta con dos puntos y entrar a carpeta data
data_route = '../data/'

# %%
#Crear variables para poder incluir n archivos (expeses1, expenses2, etc)
expenses_filename = 'expenses.csv'
incomes_filename = 'incomes.csv'

# %%
#Crear base de datos que se llame expenses
expenses = pd.read_csv(data_route+expenses_filename)
expenses = pd.read_csv(data_route+incomes_filename)

# %%
expenses
# Out:
# Empty DataFrame
# Columns: [DATE, AMOUNT, CATEGORY, THIRD PARTY, DESCRIPTION]
# Index: []
